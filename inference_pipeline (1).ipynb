# %% [markdown]
# ## Introduction
#
# This notebook processes a CSV file containing job titles, generates numerical embeddings using OpenAI's API, and utilizes a pre-trained XGBoost classifier to predict labels. The results are saved and displayed in a formatted table for easy analysis and interpretation.

# %% [markdown]
# * Load a CSV file whose titles are under the JOB_TITLE column.

# %%
import numpy as np
import pandas as pd
import pickle
import json
import os
import glob
import joblib
import time
import openai
import xgboost as xgb
from tqdm import tqdm
from rich import print
from rich.table import Table
from rich.console import Console
from rich.box import HEAVY_EDGE  



# -------------------------------
# Set the path to the input CSV file
# -------------------------------
input_csv_path = './'  # Directory containing the CSV file
input_csv_file = 'data_job_title_industry_embeddings.csv'  # Name of the CSV file

full_input_csv_path = os.path.join(input_csv_path, input_csv_file)
base_name = os.path.splitext(input_csv_file)[0]

# %% [markdown]
# ## Embedding Generation
#
# In this section, we load job titles from the specified CSV file and generate their corresponding embeddings using OpenAI's `text-embedding-ada-002` model. The embeddings are appended to the dataframe and saved as a new CSV for further processing.

# %%
openai.api_key = ""

batch_size = 100
EMBEDDING_DIM = 1536
ZERO_EMBEDDING = [0.0] * EMBEDDING_DIM

def create_embeddings_batch(texts, max_retries=3):
    embeddings = []
    non_empty_indices = [i for i, text in enumerate(texts) if isinstance(text, str) and text.strip()]
    non_empty_texts = [text for text in texts if isinstance(text, str) and text.strip()]
    for attempt in range(max_retries):
        try:
            if non_empty_texts:
                response = openai.Embedding.create(
                    input=non_empty_texts,
                    model="text-embedding-ada-002"
                )
                batch_embeddings = [item['embedding'] for item in response['data']]
                if len(batch_embeddings) != len(non_empty_texts):
                    batch_embeddings = [ZERO_EMBEDDING] * len(non_empty_texts)
                break
        except Exception as e:
            print(f"Attempt {attempt + 1} failed: {e}")
            time.sleep(2)
    else:
        batch_embeddings = [ZERO_EMBEDDING] * len(non_empty_texts)

    full_embeddings = [ZERO_EMBEDDING] * len(texts)
    for idx, emb in zip(non_empty_indices, batch_embeddings):
        if len(emb) == EMBEDDING_DIM:
            full_embeddings[idx] = emb
        else:
            full_embeddings[idx] = ZERO_EMBEDDING
    return full_embeddings

df = pd.read_csv(full_input_csv_path)
df = df.drop_duplicates(subset=['JOB_TITLE'])

embeddings = []
for i in tqdm(range(0, len(df), batch_size), desc="Generating Embeddings"):
    batch_texts = df['JOB_TITLE'].iloc[i:i + batch_size].astype(str).tolist()
    batch_embeddings = create_embeddings_batch(batch_texts)
    embeddings.extend(batch_embeddings)
    time.sleep(1)

df['embeddings'] = embeddings

output_filename = f"{base_name}_with_embeddings.csv"
output_path = os.path.join(input_csv_path, output_filename)
df.to_csv(output_path, index=False)

print(f"File saved at '{output_path}'")
# Out:
# Generating Embeddings: 100%|██████████| 6/6 [00:11<00:00,  1.90s/it]
# File saved at './data_job_title_industry_embeddings_with_embeddings.csv'

# %% [markdown]
# ## Model Loading and Prediction
#
# Here, we load the pre-trained XGBoost model and the associated label encoder from the designated directory. Using these, we perform predictions on the generated embeddings, calculate prediction probabilities, and append the results to the dataframe. The final predictions are saved to a new CSV and displayed in a color-coded table for clarity.

# %%
models_dir = "models"
data_dir = input_csv_path

model_path = os.path.join(models_dir, "best_clf.pkl")
label_encoder_path = os.path.join(models_dir, "label_encoder.pkl")
console = Console()

try:
    with open(model_path, 'rb') as file:
        loaded_clf = pickle.load(file)
    print("Model loaded successfully from 'best_clf.pkl'")
except FileNotFoundError:
    print(f"Model file '{model_path}' not found.")
    loaded_clf = None
except Exception as e:
    print(f"Error loading model: {e}")
    loaded_clf = None

try:
    label_encoder = joblib.load(label_encoder_path)
    print("Label encoder loaded successfully from 'label_encoder.pkl'")
except FileNotFoundError:
    print(f"Label encoder file '{label_encoder_path}' not found.")
    label_encoder = None
except Exception as e:
    print(f"Error loading label encoder: {e}")
    label_encoder = None

if loaded_clf is not None and label_encoder is not None:
    embeddings_csv_filename = f"{base_name}_with_embeddings.csv"
    embeddings_csv_path = os.path.join(data_dir, embeddings_csv_filename)
    
    print(f"Base Name: {base_name}")
    print(f"Embeddings CSV Filename: {embeddings_csv_filename}")
    print(f"Embeddings CSV Path: {embeddings_csv_path}")
    
    print(f"Embeddings CSV path set to '{embeddings_csv_path}'")
    
    try:
        df_embeddings = pd.read_csv(embeddings_csv_path)
        print(f"Embeddings CSV loaded from '{embeddings_csv_path}'")
    except FileNotFoundError:
        print(f"Embeddings CSV file '{embeddings_csv_path}' not found.")
        df_embeddings = None
    except Exception as e:
        print(f"Error loading embeddings CSV: {e}")
        df_embeddings = None

    if df_embeddings is not None and 'embeddings' in df_embeddings.columns:
        try:
            X_test = np.array(df_embeddings['embeddings'].apply(json.loads).tolist())
            
            y_pred = loaded_clf.predict(X_test)
            y_pred_probs = loaded_clf.predict_proba(X_test)
            
            y_pred_labels = label_encoder.inverse_transform(y_pred)
            df_embeddings['predictions'] = y_pred_labels
            
            predictions_output_filename = f"{base_name}_predictions.csv"
            predictions_output_path = os.path.join(data_dir, predictions_output_filename)
            df_embeddings.to_csv(predictions_output_path, index=False)
            print(f"Predictions saved at '{predictions_output_path}'")
            
            table = Table(show_header=True, header_style="bold magenta", box=HEAVY_EDGE, show_lines=True)
            table.add_column("Job Title", style="dim", width=50, overflow="fold")
            table.add_column("Prediction", justify="center", width=10)
            table.add_column("Probability", justify="right", width=12)
            
            for i in range(len(df_embeddings)):
                job_title = df_embeddings['JOB_TITLE'].iloc[i]
                label = df_embeddings['predictions'].iloc[i]
                
                label_color = "yellow" if label == 'False' else "blue"
                
                prob = y_pred_probs[i][0] if label == 'False' else y_pred_probs[i][1]
                prob_percentage = prob * 100
                prob_str = f"{prob_percentage:.2f}%"
                
                if prob_percentage > 90:
                    prob_color = "green"
                elif 70 < prob_percentage <= 90:
                    prob_color = "#FFA500"
                elif 50 < prob_percentage <= 70:
                    prob_color = "red"
                else:
                    prob_color = "grey"
                
                table.add_row(
                    job_title,
                    f"[{label_color}]{label}[/{label_color}]",
                    f"[{prob_color}]{prob_str}[/{prob_color}]"
                )
            
            console.print(table)
        
        except Exception as e:
            print(f"Error during prediction: {e}")
    else:
        if df_embeddings is not None:
            print("The 'embeddings' column was not found in the CSV.")
else:
    print("Model or label encoder could not be loaded. Please check the previous steps.")
# Out:
# Model loaded successfully from 'best_clf.pkl'
# Label encoder loaded successfully from 'label_encoder.pkl'
# Base Name: data_job_title_industry_embeddings
# Embeddings CSV Filename: data_job_title_industry_embeddings_with_embeddings.csv
# Embeddings CSV Path: ./data_job_title_industry_embeddings_with_embeddings.csv
# Embeddings CSV path set to './data_job_title_industry_embeddings_with_embeddings.csv'
# Embeddings CSV loaded from './data_job_title_industry_embeddings_with_embeddings.csv'
# Predictions saved at './data_job_title_industry_embeddings_predictions.csv'
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━┯━━━━━━━━━━━━━━┓
# ┃ Job Title                                          │ Prediction │  Probability ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior executive                                   │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ miller                                             │    True    │       61.37% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ trainee design engineer                            │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ relationship consultant                            │    True    │       99.75% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ wholesale credit program analyst ii                │    True    │       99.74% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior abl underwriter                             │    True    │       99.77% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ wholesale relationship associate                   │    True    │       98.84% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ operations analyst                                 │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ retired                                            │   False    │       64.12% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior documentation loan processor                │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ commercial leader - outdoor products group         │    True    │       96.14% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business execution specialist                      │    True    │       99.68% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant vice president - compliance consultant   │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ global relationship manager                        │    True    │       91.58% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ inventory finance underwriter                      │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant vice president - credit oversight        │    True    │       99.31% ┃
# ┃ associate                                          │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ field service representative                       │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior regional sales manager                      │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ warehouse associate                                │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant vice president - senior credit risk      │    True    │       99.39% ┃
# ┃ specialist                                         │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior operations adminstrator                     │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ wholesale credit program analyst i                 │    True    │       99.80% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ account manager                                    │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ underwriter                                        │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ field auditor                                      │    True    │       99.85% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ commecial distribution finance - field auditor     │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ administrative assistant                           │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ relationship associate                             │    True    │       79.15% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ operational analyst ii                             │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business system consultant                         │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior paralegal                                   │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ inside sales representative                        │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ booking administrator                              │    True    │       99.69% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ inspecteur commercial itinérant                    │    True    │       99.84% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ chief executive officer                            │    True    │       99.77% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ operations processor                               │    True    │       99.66% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ managing director                                  │    True    │       99.92% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ operations administrator                           │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior counsel                                     │    True    │       99.87% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ construction                                       │   False    │       85.83% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sous chef                                          │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ financial analyst                                  │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ parker drilling                                    │    True    │       89.79% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ hostess server                                     │    True    │       99.78% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ commercial underwritier                            │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ bartender / waiter                                 │    True    │       99.84% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ journeyman scaffolder                              │    True    │       99.53% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ production operator                                │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ property manager                                   │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ encargado de área de deposito                      │    True    │       99.92% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ student teacher                                    │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sales representative longines tissot hamilton mido │    True    │       98.19% ┃
# ┃ a ck                                               │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ ndt tech                                           │    True    │       86.55% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ production supervisor                              │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ cleaner                                            │    True    │       99.16% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager                                            │    True    │       95.15% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ économiste                                         │    True    │       98.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ marketing and process analyst                      │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ technicien d'exploitation eau et assainissement    │    True    │       99.89% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ responsable technique et commercial                │    True    │       99.84% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistante de direction                            │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ stitcher                                           │   False    │       58.61% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant supervisor                               │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ payroll clerk                                      │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ justin boot sports medicine team associate         │    True    │       99.63% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ warehouse worker                                   │    True    │       99.89% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ inspector                                          │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ machine operator                                   │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ materials department                               │    True    │       99.92% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ fitter                                             │    True    │       98.48% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ factory worker                                     │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ general labor                                      │    True    │       99.67% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ quality inspector                                  │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sales                                              │   False    │       92.60% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ internal auditor                                   │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ order entry / customer service secretary / sales   │    True    │       99.97% ┃
# ┃ administrator assistant                            │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ custodian                                          │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ lead cash clerk                                    │    True    │       99.79% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ intern                                             │    True    │       89.36% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ abap / forms developer                             │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ toe laster                                         │   False    │       83.33% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ archive manager                                    │    True    │       99.80% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ event marketing manager                            │    True    │       99.89% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ insole outsole                                     │   False    │       60.14% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ front desk agent                                   │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sales representative                               │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ fabricator                                         │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ secretary / junior industrial engineer             │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ director of marketing - justin boot company        │    True    │       98.81% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ cad system operator / design                       │    True    │       99.59% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ molder                                             │   False    │       67.27% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior sap developer / consultant                  │    True    │       99.89% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ 3rd key                                            │   False    │       99.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ programmer / analyst, project manager              │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sales & event marketing contractor justin          │    True    │       98.18% ┃
# ┃ boots-nfr                                          │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ national sales manager                             │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ cashier                                            │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sales associate                                    │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ vice president of sales                            │    True    │       99.54% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ clerical associate                                 │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ drugstore                                          │    True    │       78.18% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ division supervisor                                │    True    │       99.82% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ staff accountant                                   │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ account executive                                  │    True    │       99.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ supervisor                                         │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sales representitive                               │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ mainframe operator                                 │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ double-needle stitcher                             │    True    │       82.49% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager - product management                       │    True    │       99.89% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior relationship manager                        │    True    │       99.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ head of global software development                │    True    │       98.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ chairman                                           │    True    │       99.11% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ lead software engineer                             │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business development                               │    True    │       91.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ account consultant, project manager                │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager product management                         │    True    │       99.62% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ revenue accountant                                 │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ customer implementations engineer                  │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ managing director uk                               │    True    │       99.76% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ help desk specialist                               │    True    │       99.88% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ head of professional services                      │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ vice president legal compliance                    │    True    │       98.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior systems developer                           │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ product marketing executive                        │    True    │       99.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior specialist product management               │    True    │       99.80% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ infrastructure team leader                         │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ optimisation project lead at pulsant               │    True    │       95.61% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business financial                                 │    True    │       80.67% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior business development manager                │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior software engineer                           │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ human resources benefits director                  │    True    │       99.87% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ territory account manager                          │    True    │       99.71% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ 330 nevada st                                      │   False    │       96.20% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ director of business development                   │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ vice president , marketing                         │    True    │       99.27% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ chief compliance officer & general counsel at      │    True    │       98.95% ┃
# ┃ proficio capital partners llc                      │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior director of plant operations                │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ research assistant                                 │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ accountant                                         │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ research associate iii                             │    True    │       99.80% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ packer                                             │    True    │       98.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ vice president                                     │    True    │       97.65% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ research associate                                 │    True    │       99.71% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ director of worldwide sales                        │    True    │       98.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ general / technical                                │    True    │       99.87% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ chairman and chief executive officer               │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ technicien d'optimisation de production            │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ board observer                                     │    True    │       86.20% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior executive assistant                         │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior buyer                                       │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ commercial manager                                 │    True    │       99.58% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ cwo                                                │    True    │       68.65% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business development manager                       │    True    │       99.44% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ information technology intern                      │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ technical engineer                                 │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ technical services engineer                        │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ director of nursing                                │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ patient care technician                            │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior software engineer team lead                 │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior system architect                            │    True    │       99.87% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ banking officer                                    │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior account manager                             │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ collections representative                         │    True    │       59.92% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ collections                                        │   False    │       95.23% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business control analyst                           │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ fraud operations senior supervisor                 │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant vice president                           │    True    │       99.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ credit & collections analyst                       │    True    │       99.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ vice president bus control                         │    True    │       96.43% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ customer support specialist & authorisation        │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ collections supervisor                             │    True    │       99.81% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ information technology specialist                  │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ customer service executive                         │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ cardmember service center representative           │    True    │       99.79% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior java full stack developer                   │    True    │       99.89% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ developer                                          │    True    │       99.41% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ informatica developer                              │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ engineering lead analyst                           │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ customer service representative                    │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ executive                                          │    True    │       98.35% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ director customer care                             │    True    │       99.92% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ administrator                                      │    True    │       97.34% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ registered nurse asc                               │    True    │       99.84% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ registered nurse pacu and gi                       │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ executive - project engineering                    │    True    │       99.71% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ junior executive engineer                          │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager, civil & structural engineering, power     │    True    │       99.82% ┃
# ┃ plant design                                       │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior program manager                             │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ co-op                                              │   False    │       53.74% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ piping engineer                                    │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ pds / sp3d / pdms administrator at siemens         │    True    │       99.82% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ system engineer, power plant design                │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ execution engineer                                 │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ plant layout summer intern                         │    True    │       99.87% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ ee                                                 │   False    │       97.76% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ working                                            │   False    │       99.04% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior manager instrumentation & controls          │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ prüfer qualitätskontrolle                          │    True    │       99.81% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ site commercial                                    │    True    │       69.31% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ stress analysis engineer piping using caesar       │    True    │       99.04% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager - civil designs                            │    True    │       99.82% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ site manager                                       │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior civil engineer                              │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ marketing engineer intern                          │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior executive - human resources generalist      │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ siemens                                            │    True    │       87.02% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ electrical engineer - generator design             │    True    │       99.79% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant manager, piping                          │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ procurement team lead                              │    True    │       99.82% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ design executive                                   │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ e.h.s co-ordinator                                 │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ scaffolder                                         │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senoir engineer                                    │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager of accounting and financial planning       │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ power plant layout design                          │    True    │       94.45% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ internship trainee                                 │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ safety incharge [eohs                              │    True    │       99.85% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ team leader piping                                 │    True    │       99.80% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ thp                                                │    True    │       50.40% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ executive assistant                                │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant manager                                  │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ graduate intern                                    │    True    │       99.28% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior civil / structural engineer                 │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ engineer, civil and structural                     │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ power                                              │   False    │       95.59% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ piping                                             │   False    │       68.11% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager, electrical                                │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ tester in laboratorium                             │    True    │       98.92% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior engineer at siemens power engineering pvt   │    True    │       99.91% ┃
# ┃ ltd                                                │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ finance director - vatech t & d - siemens group    │    True    │       99.58% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant executive engineer                       │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ hospitality & administrator                        │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ electrical designer                                │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ power supply design                                │    True    │       76.64% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ smart plant3d administrator                        │    True    │       77.19% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ graduate trainee engineer                          │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ contracts manager                                  │    True    │       99.84% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ contracts                                          │   False    │       99.16% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ general manager technical                          │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ lead design engineer                               │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior designer                                    │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ engineering intern - transitions                   │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior executive - human resources                 │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business area team lead                            │    True    │       99.42% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sp3d designer                                      │   False    │       60.43% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ design engineer - piping                           │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ project management                                 │    True    │       98.14% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ summer internship                                  │    True    │       98.27% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ consultant, turbines, plant components & system    │    True    │       99.75% ┃
# ┃ engineering                                        │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ it manager                                         │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ executive engineer piping                          │    True    │       99.69% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior engineer                                    │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ epc                                                │    True    │       74.06% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ plant manager o & m                                │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ industrial placement student                       │    True    │       99.63% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ elect project engineer                             │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ técnico de ventas                                  │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ product engineer                                   │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ lead engineer - plant layout                       │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ plant layout piping,design,operation maintenance   │    True    │       99.56% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ product development specialist & project           │    True    │       99.94% ┃
# ┃ coordinator                                        │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ gas turbine                                        │    True    │       70.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ executive - siemens energy automation              │    True    │       99.75% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ estagiario                                         │    True    │       99.81% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ civil structural designer                          │    True    │       99.92% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ engineering development program                    │    True    │       99.27% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ commercial & human resource professional           │    True    │       98.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ commissioning engineer                             │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ accounting associate                               │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ design engineer-piping & layout                    │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ draftman                                           │    True    │       99.70% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ praktikum                                          │    True    │       97.70% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ design engineer- electrical                        │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager - lead mechanical engineer                 │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ civil / structural designer                        │    True    │       99.87% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ supervisor de obra                                 │    True    │       99.97% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ civil designer                                     │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ smartplant cad administrator                       │    True    │       98.66% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ manager - human resources                          │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ...
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ charitable jobs                                    │    True    │       86.63% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sqe environment and product compliance             │    True    │       86.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ q.c                                                │   False    │       70.02% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business requirements analyst                      │    True    │       99.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ expert, mentor, manager                            │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ apple data center                                  │    True    │       65.04% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ apple certified mac technician genius , retail     │    True    │       98.09% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ principal software engineer, ads platform          │    True    │       98.17% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ animal care associate                              │    True    │       99.63% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ unemplyed                                          │   False    │       98.60% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ ios tech                                           │    True    │       79.38% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior manager - battery performance labs          │    True    │       99.89% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ account security, beats, ios, and macos specialist │    True    │       99.55% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior advisor ios                                 │    True    │       99.70% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ cloud network software engineer                    │    True    │       96.26% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ resource management coordinator at aquent          │    True    │       99.84% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior manager, real estate                        │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ apple certified support professional 10.7          │    True    │       95.65% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ operations ios technical support                   │    True    │       99.45% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ digital marketing, emerging markets                │    True    │       64.37% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ global business intelligence program manager in    │    True    │       97.85% ┃
# ┃ emeia                                              │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ procurement - camera modules                       │    True    │       98.10% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ software developer contractor from infosys         │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ personnel assistant                                │    True    │       99.90% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ customer care senior advisor                       │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ global lead essentials category, senior merchant   │    True    │       94.07% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ specjalista ds technologii                         │    True    │       99.76% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ maria                                              │   False    │       90.71% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ formation apple foundation program i               │    True    │       89.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ channel systems & ops pm                           │    True    │       99.60% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ personalized marketing                             │   False    │       58.35% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ encargado de almacén                               │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ key holder, applications trainer, genius bar       │    True    │       99.93% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ touch sensor hw validation lab technician          │    True    │       99.45% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ apple tv qa                                        │    True    │       83.00% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ spanish & catalan localization team leader         │    True    │       99.80% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ social program manager, events lead                │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ research executive                                 │    True    │       99.84% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior compliance consultant                       │    True    │       99.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ artificial intelligence / data science / practice  │    True    │       95.91% ┃
# ┃ leader                                             │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior internal auditor                            │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ maintenance engineer                               │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ rfo inventory operations program support           │    True    │       94.91% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ supervise                                          │    True    │       99.55% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ information systems & t training                   │    True    │       98.05% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ gamiba                                             │   False    │       90.59% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ technical team leader                              │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ certified systems administrator                    │    True    │       99.62% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ project manager, retail merchandising              │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ hotil                                              │    True    │       53.34% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ forward                                            │   False    │       98.07% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ specialist and merchandising & technology          │    True    │       99.97% ┃
# ┃ specialist                                         │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ software engineering manager, icloud engineering   │    True    │       99.56% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ software tutor                                     │    True    │       99.15% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ développeur d algorithmes                          │    True    │       97.88% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior software integrity engineer tentpole        │    True    │       99.92% ┃
# ┃ integration qa                                     │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ onetoone trainer                                   │   False    │       75.34% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ specialist & team mentor                           │    True    │       99.95% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ technical specialist - technical support           │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ creador del iphone                                 │   False    │       93.01% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business analyst, iphone                           │    True    │       99.76% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ 339089                                             │   False    │       82.56% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ quality engineer & lab manager                     │    True    │       99.99% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assistant visual manager                           │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ operations and technical manager                   │    True    │       99.98% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ ex credit controller                               │    True    │       99.81% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ professor of imaging machinations                  │    True    │       97.58% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ worldwide rfo supply demand                        │   False    │       75.17% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ music operations - lyrics curation                 │   False    │       73.35% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ business to business communications - emeia        │    True    │       93.58% ┃
# ┃ content                                            │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ usb qa engineer                                    │    True    │       99.64% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ ditary                                             │   False    │       58.21% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ graphics and imaging intern                        │    True    │       99.68% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ schedule administrator career experience           │    True    │       99.72% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ مؤسس                                               │    True    │       73.79% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ مساعد عقارات                                       │   False    │       53.79% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ iphone operations test engineer                    │    True    │       99.94% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ assembly re-worker                                 │    True    │       99.37% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ ios power engineer                                 │    True    │       99.69% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ team manager - backfill                            │    True    │       99.24% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior engineering manager - site reliability      │    True    │       99.84% ┃
# ┃ engineering and operations                         │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ sales support management representative            │    True    │       99.92% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ corporate recruiting leader & regional diversity   │    True    │       99.52% ┃
# ┃ recruiting leader                                  │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ ios frameworks software test developer             │    True    │       98.48% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ regional business to business marketing lead,      │    True    │       95.73% ┃
# ┃ latin america                                      │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ amp financial system and analytics                 │    True    │       88.85% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior software engineer, web user interface & 3d  │    True    │       99.97% ┃
# ┃ graphics                                           │            │              ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ mobile shop                                        │    True    │       96.70% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ lease payment analyst - real estate & development  │    True    │       99.96% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ senior manager, software marketing                 │    True    │       99.86% ┃
# ┠────────────────────────────────────────────────────┼────────────┼──────────────┨
# ┃ software engineer - commerce                       │    True    │       99.90% ┃
# ┗━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━┷━━━━━━━━━━━━━━┛

# %% [markdown]
# ## Conclusion
#
# The pipeline successfully ingests job titles, generates their embeddings, and leverages a machine learning model to predict labels. The structured and color-coded output facilitates easy interpretation of the results.
